# %% [markdown]
# # Lab 1: Building your own n-gram language model
#
# In this lab, you will build your own language model based on n-grams and the Maximum Likelihood Estimation.
#
# We'll assume that our text is already "tokenized" (split up into words). We'll cover this process in more depth in the next module.
#
# As an example, let's work with two sentences from "[The Disappearance of Lady Frances Carfax](https://en.wikipedia.org/wiki/The_Disappearance_of_Lady_Frances_Carfax)", a short story written by [Sir Arthur Conan Doyle](https://en.wikipedia.org/wiki/Arthur_Conan_Doyle).

# %%
# Tokens for the sentence "It shows, my dear Watson, that we are dealing
# with an exceptionally astude and dangerous man."
sample1 = ['It', 'shows', ',', 'my', 'dear', 'Watson', ',', 'that',
           'we', 'are', 'dealing', 'with', 'an', 'exceptionally',
           'astute', 'and', 'dangerous', 'man', '.']
# Tokens for the sentence "How would Lausanne do, my dear Watson?"
sample2 = ['How', 'would', 'Lausanne', 'do', ',', 'my', 'dear',
           'Watson', '?']

# %% [markdown]
# Your first task is to write a function that splits the `tokens` sequence
# into its `n`-grams.
#
# For instance, when `tokens=sample1` and `n=3`, your function should
# return:
#
# ```python
# [('It', 'shows', ','),
#  ('shows', ',', 'my'),
#  (',', 'my', 'dear'),
#  ...,
#  ('dangerous', 'man', '.')]
# ```
#
# Note: You should return a python [`list`](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists) containing [`tuple`](https://docs.python.org/3/tutorial/datastructures.html#tuples-and-sequences)s. `tuple`s are immutable sequences, which will be useful later on when you build your language model.

# %%
from typing import List, Tuple
def build_ngrams(tokens: List[str], n: int) -> List[Tuple[str]]:
    # your code here
    ngrams = []
    for i in range(len(tokens)-n+1):
        ngram = tuple(tokens[i:i+n])
        ngrams.append(ngram)
    return ngrams, len(ngrams)

# Example:
build_ngrams(sample2, n=2)
# Out:
# ([('How', 'would'),
#   ('would', 'Lausanne'),
#   ('Lausanne', 'do'),
#   ('do', ','),
#   (',', 'my'),
#   ('my', 'dear'),
#   ('dear', 'Watson'),
#   ('Watson', '?')],
#  8)

# %%
# Tests:
assert len(build_ngrams(sample1, n=3)) == 17
assert build_ngrams(sample1, n=3)[0] == ('It', 'shows', ',')
assert build_ngrams(sample1, n=3)[10] == ('dealing', 'with', 'an')
assert len(build_ngrams(sample1, n=2)) == 18
assert build_ngrams(sample1, n=2)[0] == ('It', 'shows')
assert build_ngrams(sample1, n=2)[10] == ('dealing', 'with')
assert len(build_ngrams(sample2, n=2)) == 8
assert build_ngrams(sample2, n=2)[0] == ('How', 'would')
assert build_ngrams(sample2, n=2)[7] == ('Watson', '?')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-076bb3b9fc92> in <module>
#       1 # Tests:
# ----> 2 assert len(build_ngrams(sample1, n=3)) == 17
#       3 assert build_ngrams(sample1, n=3)[0] == ('It', 'shows', ',')
#       4 assert build_ngrams(sample1, n=3)[10] == ('dealing', 'with', 'an')
#       5 assert len(build_ngrams(sample1, n=2)) == 18
#
# AssertionError:

# %% [markdown]
# With the current function, there's no way to know whether an n-gram is at the beginning, middle, or end of the sequence. To overcome this problem, n-gram language models often include special "beginning-of-string" (BOS) and "end-of-string" (EOS) control tokens.
#
# Write a new version of your `build_ngrams` function that includes these control tokens. For instance, when `tokens=sample1` and `n=3`, your new function should return:
#
# ```python
# [('<BOS>', '<BOS>', 'It'),
#  ('<BOS>', 'It', 'shows'),
#  ('It', 'shows', ','),
#  ('shows', ',', 'my'),
#  (',', 'my', 'dear'),
#  ...,
#  ('dangerous', 'man', '.'),
#  ('man', '.', '<EOS>'),
#  ('.', '<EOS>', '<EOS>')]
# ```

# %%
BOS = '<BOS>'
EOS = '<EOS>'

def build_ngrams_ctrl(tokens: List[str], n: int) -> List[Tuple[str]]:
    # your code here
    tokens = [BOS] * (n-1) + tokens + [EOS] * (n-1)
    ngrams=[]
    
    for i in range (len(tokens)-n+1):
        ngram = tuple(tokens[i:i+n])
        ngrams.append(ngram)
    return ngrams

# Example:
build_ngrams_ctrl(sample1, n=3)
# Out:
# [('<BOS>', '<BOS>', 'It'),
#  ('<BOS>', 'It', 'shows'),
#  ('It', 'shows', ','),
#  ('shows', ',', 'my'),
#  (',', 'my', 'dear'),
#  ('my', 'dear', 'Watson'),
#  ('dear', 'Watson', ','),
#  ('Watson', ',', 'that'),
#  (',', 'that', 'we'),
#  ('that', 'we', 'are'),
#  ('we', 'are', 'dealing'),
#  ('are', 'dealing', 'with'),
#  ('dealing', 'with', 'an'),
#  ('with', 'an', 'exceptionally'),
#  ('an', 'exceptionally', 'astute'),
#  ('exceptionally', 'astute', 'and'),
#  ('astute', 'and', 'dangerous'),
#  ('and', 'dangerous', 'man'),
#  ('dangerous', 'man', '.'),
#  ('man', '.', '<EOS>'),
#  ('.', '<EOS>', '<EOS>')]

# %%
# Tests:
assert len(build_ngrams_ctrl(sample1, n=3)) == 21
assert build_ngrams_ctrl(sample1, n=3)[0] == ('<BOS>', '<BOS>', 'It')
assert build_ngrams_ctrl(sample1, n=3)[10] == ('we', 'are', 'dealing')
assert len(build_ngrams_ctrl(sample1, n=2)) == 20
assert build_ngrams_ctrl(sample1, n=2)[0] == ('<BOS>', 'It')
assert build_ngrams_ctrl(sample1, n=2)[10] == ('are', 'dealing')
assert len(build_ngrams_ctrl(sample2, n=2)) == 10
assert build_ngrams_ctrl(sample2, n=2)[0] == ('<BOS>', 'How')
assert build_ngrams_ctrl(sample2, n=2)[9] == ('?', '<EOS>')

# %% [markdown]
# Now that you can build n-grams, we have almost everything we need to build an n-gram language model.
#
# To compute Maximum Likelihood Estimations, you first need to count the number of times each word follows an n-gram of size `n-1`. You can build this structure as a Python [`dict`](https://docs.python.org/3/tutorial/datastructures.html#dictionaries) that maps the n-grams of size `n-1` to another `dict` that maps the following words to their respective counts.
#
# For instance, when `texts=[sample1, sample2]` and `n=3`, your function should return:
#
# ```python
# {
#     ('<BOS>', '<BOS>'): {'It': 1, 'How': 1},
#     ('<BOS>', 'It'): {'shows': 1},
#     ('<BOS>', 'How'): {'would': 1},
#     ...
#     ('my', 'dear'): {'Watson': 2},
#     ('dear', 'Watson'): {',': 1, '?': 1},
#     ...
# }
# ```

# %%
from typing import Dict
def count_ngrams(texts: List[List[str]], n: int) -> Dict[Tuple[str, ...], Dict[str, int]]:
    # your code here
    # Be sure to use your build_ngrams_ctrl implementation
    ngram_counts = {}

    for text_num, text in enumerate(texts, start=1):
        print(f"Procesando texto {text_num}...")
        ngrams = build_ngrams_ctrl(text, n)
        print(f"Generados {len(ngrams)} n-gramas de tamaño {n}")
        
        for ngram_num, ngram in enumerate(ngrams, start=1):
            prefix = tuple(ngram[:-1])  # n-1 gram
            word = ngram[-1]  # Última palabra en el n-grama
            

            if prefix not in ngram_counts:
                ngram_counts[prefix] = {}
            if word not in ngram_counts[prefix]:
                ngram_counts[prefix][word] = 1
            else:
                ngram_counts[prefix][word] += 1
                
    return ngram_counts

# Example:
count_ngrams([sample1, sample2], n=3)
# Out:
# Procesando texto 1...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 2...
# Generados 11 n-gramas de tamaño 3
# {('<BOS>', '<BOS>'): {'It': 1, 'How': 1},
#  ('<BOS>', 'It'): {'shows': 1},
#  ('It', 'shows'): {',': 1},
#  ('shows', ','): {'my': 1},
#  (',', 'my'): {'dear': 2},
#  ('my', 'dear'): {'Watson': 2},
#  ('dear', 'Watson'): {',': 1, '?': 1},
#  ('Watson', ','): {'that': 1},
#  (',', 'that'): {'we': 1},
#  ('that', 'we'): {'are': 1},
#  ('we', 'are'): {'dealing': 1},
#  ('are', 'dealing'): {'with': 1},
#  ('dealing', 'with'): {'an': 1},
#  ('with', 'an'): {'exceptionally': 1},
#  ('an', 'exceptionally'): {'astute': 1},
#  ('exceptionally', 'astute'): {'and': 1},
#  ('astute', 'and'): {'dangerous': 1},
#  ('and', 'dangerous'): {'man': 1},
#  ('dangerous', 'man'): {'.': 1},
#  ('man', '.'): {'<EOS>': 1},
#  ('.', '<EOS>'): {'<EOS>': 1},
#  ('<BOS>', 'How'): {'would': 1},
#  ('How', 'would'): {'Lausanne': 1},
#  ('would', 'Lausanne'): {'do': 1},
#  ('Lausanne', 'do'): {',': 1},
#  ('do', ','): {'my': 1},
#  ('Watson', '?'): {'<EOS>': 1},
#  ('?', '<EOS>'): {'<EOS>': 1}}

# %% [markdown]
# Como se puede notar, el numero de engramas no coincide con el numero de entradas del diccionario. Aquí pueden pasar dos cosas:
#
# 1. Que ambas entradas compartan un mismo n-grama, con la misma palabra final como en:('my', 'dear'): {'Watson': 2}
# 2. Que para un engrama, el mismo n-grama venga seguido de palabras distintas:('dear', 'Watson'): {',': 1, '?': 1}

# %%
# Tests:
assert len(count_ngrams([sample1, sample2], n=3)) == 28
assert len(count_ngrams([sample1, sample2], n=3)['<BOS>', '<BOS>']) == 2
assert count_ngrams([sample1, sample2], n=3)['<BOS>', '<BOS>']['It'] == 1
assert count_ngrams([sample1, sample2], n=3)['<BOS>', '<BOS>']['How'] == 1
assert count_ngrams([sample1, sample2], n=3)['my', 'dear']['Watson'] == 2
assert len(count_ngrams([sample1, sample2], n=2)) == 24
assert len(count_ngrams([sample1, sample2], n=2)['<BOS>',]) == 2
assert count_ngrams([sample1, sample2], n=2)['<BOS>',]['It'] == 1
assert count_ngrams([sample1, sample2], n=2)['<BOS>',]['How'] == 1
assert count_ngrams([sample1, sample2], n=2)['dear',]['Watson'] == 2

# %% [markdown]
# You're almost there! The last step is to convert the counts into probability estimates.
#
# When `texts=[sample1, sample2]` and `n=3`, your function should return:
#
# ```python
# {
#     ('<BOS>', '<BOS>'): {'It': 0.5, 'How': 0.5},
#     ('<BOS>', 'It'): {'shows': 1.0},
#     ('<BOS>', 'How'): {'would': 1.0},
#     ...
#     ('my', 'dear'): {'Watson': 1.0},
#     ('dear', 'Watson'): {',': 0.5, '?': 0.5},
#     ...
# }
# ```

# %%
from typing import Dict
def build_ngram_model(texts: List[List[str]], n: int) -> Dict[Tuple[str, ...], Dict[str, float]]:
    
    # your code here
    # Be sure to use your count_ngrams implementation
    ngram_counts = count_ngrams(texts, n)
    ngram_model = {}

    for prefix, word_counts in ngram_counts.items():
        total_count = sum(word_counts.values())
        probabilities = {word: count / total_count for word, count in word_counts.items()}
        ngram_model[prefix] = probabilities

    return ngram_model


# Example:
build_ngram_model([sample1, sample2], n=3)
# Out:
# Procesando texto 1...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 2...
# Generados 11 n-gramas de tamaño 3
# {('<BOS>', '<BOS>'): {'It': 0.5, 'How': 0.5},
#  ('<BOS>', 'It'): {'shows': 1.0},
#  ('It', 'shows'): {',': 1.0},
#  ('shows', ','): {'my': 1.0},
#  (',', 'my'): {'dear': 1.0},
#  ('my', 'dear'): {'Watson': 1.0},
#  ('dear', 'Watson'): {',': 0.5, '?': 0.5},
#  ('Watson', ','): {'that': 1.0},
#  (',', 'that'): {'we': 1.0},
#  ('that', 'we'): {'are': 1.0},
#  ('we', 'are'): {'dealing': 1.0},
#  ('are', 'dealing'): {'with': 1.0},
#  ('dealing', 'with'): {'an': 1.0},
#  ('with', 'an'): {'exceptionally': 1.0},
#  ('an', 'exceptionally'): {'astute': 1.0},
#  ('exceptionally', 'astute'): {'and': 1.0},
#  ('astute', 'and'): {'dangerous': 1.0},
#  ('and', 'dangerous'): {'man': 1.0},
#  ('dangerous', 'man'): {'.': 1.0},
#  ('man', '.'): {'<EOS>': 1.0},
#  ('.', '<EOS>'): {'<EOS>': 1.0},
#  ('<BOS>', 'How'): {'would': 1.0},
#  ('How', 'would'): {'Lausanne': 1.0},
#  ('would', 'Lausanne'): {'do': 1.0},
#  ('Lausanne', 'do'): {',': 1.0},
#  ('do', ','): {'my': 1.0},
#  ('Watson', '?'): {'<EOS>': 1.0},
#  ('?', '<EOS>'): {'<EOS>': 1.0}}

# %%
# Tests:
assert build_ngram_model([sample1, sample2], n=3)['<BOS>', '<BOS>']['It'] == 0.5
assert build_ngram_model([sample1, sample2], n=3)['<BOS>', '<BOS>']['How'] == 0.5
assert build_ngram_model([sample1, sample2], n=3)['my', 'dear']['Watson'] == 1.0
assert build_ngram_model([sample1, sample2], n=2)['<BOS>',]['It'] == 0.5
assert build_ngram_model([sample1, sample2], n=2)['<BOS>',]['How'] == 0.5
assert build_ngram_model([sample1, sample2], n=2)['dear',]['Watson'] == 1.0

# %% [markdown]
# A language model built from only a few sentences is not very informative. Let's scale up and see what your language model looks like when we train on the complete works of Sir Arthur Conon Doyle!

# %%
full_text = []
with open('arthur-conan-doyle.tok.train.txt', 'rt') as fin:
    for line in fin:
        full_text.append(list(line.split()))
model = build_ngram_model(full_text, n=3)
# Out:
# Procesando texto 1...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 2...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 3...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 4...
# Generados 99 n-gramas de tamaño 3
# Procesando texto 5...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 6...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 7...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 8...
# Generados 125 n-gramas de tamaño 3
# Procesando texto 9...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 10...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 11...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 12...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 13...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 14...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 15...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 16...
# Generados 107 n-gramas de tamaño 3
# Procesando texto 17...
# Generados 113 n-gramas de tamaño 3
# Procesando texto 18...
# Generados 58 n-gramas de tamaño 3
# Procesando texto 19...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 20...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 21...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 22...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 23...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 24...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 25...
# Generados 80 n-gramas de tamaño 3
# Procesando texto 26...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 27...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 28...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 29...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 30...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 31...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 32...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 33...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 34...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 35...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 36...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 37...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 38...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 39...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 40...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 41...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 42...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 43...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 44...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 45...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 46...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 47...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 48...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 49...
# Generados 71 n-gramas de tamaño 3
# Procesando texto 50...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 51...
# Generados 107 n-gramas de tamaño 3
# Procesando texto 52...
# Generados 87 n-gramas de tamaño 3
# Procesando texto 53...
# Generados 115 n-gramas de tamaño 3
# Procesando texto 54...
# Generados 271 n-gramas de tamaño 3
# Procesando texto 55...
# Generados 168 n-gramas de tamaño 3
# Procesando texto 56...
# Generados 235 n-gramas de tamaño 3
# Procesando texto 57...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 58...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 59...
# Generados 321 n-gramas de tamaño 3
# Procesando texto 60...
# Generados 78 n-gramas de tamaño 3
# Procesando texto 61...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 62...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 63...
# Generados 55 n-gramas de tamaño 3
# Procesando texto 64...
# Generados 30 n-gramas de tamaño 3
# Procesando texto 65...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 66...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 67...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 68...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 69...
# Generados 76 n-gramas de tamaño 3
# Procesando texto 70...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 71...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 72...
# Generados 90 n-gramas de tamaño 3
# Procesando texto 73...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 74...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 75...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 76...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 77...
# Generados 123 n-gramas de tamaño 3
# Procesando texto 78...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 79...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 80...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 81...
# Generados 115 n-gramas de tamaño 3
# Procesando texto 82...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 83...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 84...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 85...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 86...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 87...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 88...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 89...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 90...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 91...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 92...
# Generados 69 n-gramas de tamaño 3
# Procesando texto 93...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 94...
# Generados 45 n-gramas de tamaño 3
# Procesando texto 95...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 96...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 97...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 98...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 99...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 100...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 101...
# Generados 70 n-gramas de tamaño 3
# Procesando texto 102...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 103...
# Generados 115 n-gramas de tamaño 3
# Procesando texto 104...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 105...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 106...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 107...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 108...
# Generados 201 n-gramas de tamaño 3
# Procesando texto 109...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 110...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 111...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 112...
# Generados 171 n-gramas de tamaño 3
# Procesando texto 113...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 114...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 115...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 116...
# Generados 97 n-gramas de tamaño 3
# Procesando texto 117...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 118...
# Generados 76 n-gramas de tamaño 3
# Procesando texto 119...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 120...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 121...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 122...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 123...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 124...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 125...
# Generados 195 n-gramas de tamaño 3
# Procesando texto 126...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 127...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 128...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 129...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 130...
# Generados 91 n-gramas de tamaño 3
# Procesando texto 131...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 132...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 133...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 134...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 135...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 136...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 137...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 138...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 139...
# Generados 68 n-gramas de tamaño 3
# Procesando texto 140...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 141...
# Generados 143 n-gramas de tamaño 3
# Procesando texto 142...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 143...
# Generados 69 n-gramas de tamaño 3
# Procesando texto 144...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 145...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 146...
# Generados 65 n-gramas de tamaño 3
# Procesando texto 147...
# Generados 122 n-gramas de tamaño 3
# Procesando texto 148...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 149...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 150...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 151...
# Generados 121 n-gramas de tamaño 3
# Procesando texto 152...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 153...
# Generados 54 n-gramas de tamaño 3
# Procesando texto 154...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 155...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 156...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 157...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 158...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 159...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 160...
# Generados 45 n-gramas de tamaño 3
# Procesando texto 161...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 162...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 163...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 164...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 165...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 166...
# Generados 58 n-gramas de tamaño 3
# Procesando texto 167...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 168...
# Generados 78 n-gramas de tamaño 3
# Procesando texto 169...
# Generados 114 n-gramas de tamaño 3
# Procesando texto 170...
# Generados 85 n-gramas de tamaño 3
# Procesando texto 171...
# Generados 96 n-gramas de tamaño 3
# Procesando texto 172...
# Generados 88 n-gramas de tamaño 3
# Procesando texto 173...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 174...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 175...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 176...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 177...
# Generados 351 n-gramas de tamaño 3
# Procesando texto 178...
# Generados 54 n-gramas de tamaño 3
# Procesando texto 179...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 180...
# Generados 30 n-gramas de tamaño 3
# Procesando texto 181...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 182...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 183...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 184...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 185...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 186...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 187...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 188...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 189...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 190...
# Generados 65 n-gramas de tamaño 3
# Procesando texto 191...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 192...
# Generados 40 n-gramas de tamaño 3
# Procesando texto 193...
# Generados 65 n-gramas de tamaño 3
# Procesando texto 194...
# Generados 107 n-gramas de tamaño 3
# Procesando texto 195...
# Generados 166 n-gramas de tamaño 3
# Procesando texto 196...
# Generados 137 n-gramas de tamaño 3
# Procesando texto 197...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 198...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 199...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 200...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 201...
# Generados 195 n-gramas de tamaño 3
# Procesando texto 202...
# Generados 193 n-gramas de tamaño 3
# Procesando texto 203...
# Generados 167 n-gramas de tamaño 3
# Procesando texto 204...
# Generados 132 n-gramas de tamaño 3
# Procesando texto 205...
# Generados 204 n-gramas de tamaño 3
# Procesando texto 206...
# Generados 137 n-gramas de tamaño 3
# Procesando texto 207...
# Generados 174 n-gramas de tamaño 3
# Procesando texto 208...
# Generados 122 n-gramas de tamaño 3
# Procesando texto 209...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 210...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 211...
# Generados 111 n-gramas de tamaño 3
# Procesando texto 212...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 213...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 214...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 215...
# Generados 74 n-gramas de tamaño 3
# Procesando texto 216...
# Generados 134 n-gramas de tamaño 3
# Procesando texto 217...
# Generados 48 n-gramas de tamaño 3
# Procesando texto 218...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 219...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 220...
# Generados 45 n-gramas de tamaño 3
# Procesando texto 221...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 222...
# Generados 5 n-gramas de tamaño 3
# Procesando texto 223...
# Generados 78 n-gramas de tamaño 3
# Procesando texto 224...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 225...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 226...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 227...
# Generados 84 n-gramas de tamaño 3
# Procesando texto 228...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 229...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 230...
# Generados 190 n-gramas de tamaño 3
# Procesando texto 231...
# Generados 104 n-gramas de tamaño 3
# Procesando texto 232...
# Generados 113 n-gramas de tamaño 3
# Procesando texto 233...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 234...
# Generados 109 n-gramas de tamaño 3
# Procesando texto 235...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 236...
# Generados 130 n-gramas de tamaño 3
# Procesando texto 237...
# Generados 200 n-gramas de tamaño 3
# Procesando texto 238...
# Generados 180 n-gramas de tamaño 3
# Procesando texto 239...
# Generados 301 n-gramas de tamaño 3
# Procesando texto 240...
# Generados 248 n-gramas de tamaño 3
# Procesando texto 241...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 242...
# Generados 30 n-gramas de tamaño 3
# Procesando texto 243...
# Generados 48 n-gramas de tamaño 3
# Procesando texto 244...
# Generados 77 n-gramas de tamaño 3
# Procesando texto 245...
# Generados 171 n-gramas de tamaño 3
# Procesando texto 246...
# Generados 147 n-gramas de tamaño 3
# Procesando texto 247...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 248...
# Generados 165 n-gramas de tamaño 3
# Procesando texto 249...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 250...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 251...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 252...
# Generados 70 n-gramas de tamaño 3
# Procesando texto 253...
# Generados 57 n-gramas de tamaño 3
# Procesando texto 254...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 255...
# Generados 174 n-gramas de tamaño 3
# Procesando texto 256...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 257...
# Generados 76 n-gramas de tamaño 3
# Procesando texto 258...
# Generados 91 n-gramas de tamaño 3
# Procesando texto 259...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 260...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 261...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 262...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 263...
# Generados 84 n-gramas de tamaño 3
# Procesando texto 264...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 265...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 266...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 267...
# Generados 68 n-gramas de tamaño 3
# Procesando texto 268...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 269...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 270...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 271...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 272...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 273...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 274...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 275...
# Generados 5 n-gramas de tamaño 3
# Procesando texto 276...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 277...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 278...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 279...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 280...
# Generados 287 n-gramas de tamaño 3
# Procesando texto 281...
# Generados 52 n-gramas de tamaño 3
# Procesando texto 282...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 283...
# Generados 84 n-gramas de tamaño 3
# Procesando texto 284...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 285...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 286...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 287...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 288...
# Generados 83 n-gramas de tamaño 3
# Procesando texto 289...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 290...
# Generados 118 n-gramas de tamaño 3
# Procesando texto 291...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 292...
# Generados 84 n-gramas de tamaño 3
# Procesando texto 293...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 294...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 295...
# Generados 102 n-gramas de tamaño 3
# Procesando texto 296...
# Generados 75 n-gramas de tamaño 3
# Procesando texto 297...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 298...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 299...
# Generados 97 n-gramas de tamaño 3
# Procesando texto 300...
# Generados 51 n-gramas de tamaño 3
# Procesando texto 301...
# Generados 91 n-gramas de tamaño 3
# Procesando texto 302...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 303...
# Generados 48 n-gramas de tamaño 3
# Procesando texto 304...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 305...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 306...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 307...
# Generados 194 n-gramas de tamaño 3
# Procesando texto 308...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 309...
# Generados 133 n-gramas de tamaño 3
# Procesando texto 310...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 311...
# Generados 97 n-gramas de tamaño 3
# Procesando texto 312...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 313...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 314...
# Generados 164 n-gramas de tamaño 3
# Procesando texto 315...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 316...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 317...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 318...
# Generados 106 n-gramas de tamaño 3
# Procesando texto 319...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 320...
# Generados 74 n-gramas de tamaño 3
# Procesando texto 321...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 322...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 323...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 324...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 325...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 326...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 327...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 328...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 329...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 330...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 331...
# Generados 57 n-gramas de tamaño 3
# Procesando texto 332...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 333...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 334...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 335...
# Generados 88 n-gramas de tamaño 3
# Procesando texto 336...
# Generados 90 n-gramas de tamaño 3
# Procesando texto 337...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 338...
# Generados 108 n-gramas de tamaño 3
# Procesando texto 339...
# Generados 92 n-gramas de tamaño 3
# Procesando texto 340...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 341...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 342...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 343...
# Generados 69 n-gramas de tamaño 3
# Procesando texto 344...
# Generados 80 n-gramas de tamaño 3
# Procesando texto 345...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 346...
# Generados 80 n-gramas de tamaño 3
# Procesando texto 347...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 348...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 349...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 350...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 351...
# Generados 90 n-gramas de tamaño 3
# Procesando texto 352...
# Generados 87 n-gramas de tamaño 3
# Procesando texto 353...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 354...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 355...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 356...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 357...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 358...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 359...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 360...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 361...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 362...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 363...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 364...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 365...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 366...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 367...
# Generados 62 n-gramas de tamaño 3
# Procesando texto 368...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 369...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 370...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 371...
# Generados 122 n-gramas de tamaño 3
# Procesando texto 372...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 373...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 374...
# Generados 45 n-gramas de tamaño 3
# Procesando texto 375...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 376...
# Generados 125 n-gramas de tamaño 3
# Procesando texto 377...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 378...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 379...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 380...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 381...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 382...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 383...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 384...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 385...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 386...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 387...
# Generados 76 n-gramas de tamaño 3
# Procesando texto 388...
# Generados 62 n-gramas de tamaño 3
# Procesando texto 389...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 390...
# Generados 58 n-gramas de tamaño 3
# Procesando texto 391...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 392...
# Generados 53 n-gramas de tamaño 3
# Procesando texto 393...
# Generados 77 n-gramas de tamaño 3
# Procesando texto 394...
# Generados 74 n-gramas de tamaño 3
# Procesando texto 395...
# Generados 95 n-gramas de tamaño 3
# Procesando texto 396...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 397...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 398...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 399...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 400...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 401...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 402...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 403...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 404...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 405...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 406...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 407...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 408...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 409...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 410...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 411...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 412...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 413...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 414...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 415...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 416...
# Generados 69 n-gramas de tamaño 3
# Procesando texto 417...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 418...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 419...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 420...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 421...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 422...
# Generados 61 n-gramas de tamaño 3
# Procesando texto 423...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 424...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 425...
# Generados 70 n-gramas de tamaño 3
# Procesando texto 426...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 427...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 428...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 429...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 430...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 431...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 432...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 433...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 434...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 435...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 436...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 437...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 438...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 439...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 440...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 441...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 442...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 443...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 444...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 445...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 446...
# Generados 66 n-gramas de tamaño 3
# Procesando texto 447...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 448...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 449...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 450...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 451...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 452...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 453...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 454...
# Generados 30 n-gramas de tamaño 3
# Procesando texto 455...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 456...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 457...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 458...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 459...
# Generados 130 n-gramas de tamaño 3
# Procesando texto 460...
# Generados 57 n-gramas de tamaño 3
# Procesando texto 461...
# Generados 138 n-gramas de tamaño 3
# Procesando texto 462...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 463...
# Generados 201 n-gramas de tamaño 3
# Procesando texto 464...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 465...
# Generados 199 n-gramas de tamaño 3
# Procesando texto 466...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 467...
# Generados 122 n-gramas de tamaño 3
# Procesando texto 468...
# Generados 181 n-gramas de tamaño 3
# Procesando texto 469...
# Generados 70 n-gramas de tamaño 3
# Procesando texto 470...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 471...
# Generados 57 n-gramas de tamaño 3
# Procesando texto 472...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 473...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 474...
# Generados 86 n-gramas de tamaño 3
# Procesando texto 475...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 476...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 477...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 478...
# Generados 86 n-gramas de tamaño 3
# Procesando texto 479...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 480...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 481...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 482...
# Generados 100 n-gramas de tamaño 3
# Procesando texto 483...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 484...
# Generados 145 n-gramas de tamaño 3
# Procesando texto 485...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 486...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 487...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 488...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 489...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 490...
# Generados 60 n-gramas de tamaño 3
# Procesando texto 491...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 492...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 493...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 494...
# Generados 51 n-gramas de tamaño 3
# Procesando texto 495...
# Generados 48 n-gramas de tamaño 3
# Procesando texto 496...
# Generados 91 n-gramas de tamaño 3
# Procesando texto 497...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 498...
# Generados 101 n-gramas de tamaño 3
# Procesando texto 499...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 500...
# Generados 73 n-gramas de tamaño 3
# Procesando texto 501...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 502...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 503...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 504...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 505...
# Generados 122 n-gramas de tamaño 3
# Procesando texto 506...
# Generados 40 n-gramas de tamaño 3
# Procesando texto 507...
# Generados 117 n-gramas de tamaño 3
# Procesando texto 508...
# Generados 63 n-gramas de tamaño 3
# Procesando texto 509...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 510...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 511...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 512...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 513...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 514...
# Generados 5 n-gramas de tamaño 3
# Procesando texto 515...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 516...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 517...
# Generados 56 n-gramas de tamaño 3
# Procesando texto 518...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 519...
# Generados 54 n-gramas de tamaño 3
# Procesando texto 520...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 521...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 522...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 523...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 524...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 525...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 526...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 527...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 528...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 529...
# Generados 226 n-gramas de tamaño 3
# Procesando texto 530...
# Generados 74 n-gramas de tamaño 3
# Procesando texto 531...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 532...
# Generados 202 n-gramas de tamaño 3
# Procesando texto 533...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 534...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 535...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 536...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 537...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 538...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 539...
# Generados 89 n-gramas de tamaño 3
# Procesando texto 540...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 541...
# Generados 193 n-gramas de tamaño 3
# Procesando texto 542...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 543...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 544...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 545...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 546...
# Generados 376 n-gramas de tamaño 3
# Procesando texto 547...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 548...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 549...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 550...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 551...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 552...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 553...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 554...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 555...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 556...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 557...
# Generados 30 n-gramas de tamaño 3
# Procesando texto 558...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 559...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 560...
# Generados 132 n-gramas de tamaño 3
# Procesando texto 561...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 562...
# Generados 88 n-gramas de tamaño 3
# Procesando texto 563...
# Generados 168 n-gramas de tamaño 3
# Procesando texto 564...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 565...
# Generados 153 n-gramas de tamaño 3
# Procesando texto 566...
# Generados 121 n-gramas de tamaño 3
# Procesando texto 567...
# Generados 186 n-gramas de tamaño 3
# Procesando texto 568...
# Generados 105 n-gramas de tamaño 3
# Procesando texto 569...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 570...
# Generados 343 n-gramas de tamaño 3
# Procesando texto 571...
# Generados 223 n-gramas de tamaño 3
# Procesando texto 572...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 573...
# Generados 70 n-gramas de tamaño 3
# Procesando texto 574...
# Generados 96 n-gramas de tamaño 3
# Procesando texto 575...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 576...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 577...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 578...
# Generados 399 n-gramas de tamaño 3
# Procesando texto 579...
# Generados 68 n-gramas de tamaño 3
# Procesando texto 580...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 581...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 582...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 583...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 584...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 585...
# Generados 87 n-gramas de tamaño 3
# Procesando texto 586...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 587...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 588...
# Generados 65 n-gramas de tamaño 3
# Procesando texto 589...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 590...
# Generados 118 n-gramas de tamaño 3
# Procesando texto 591...
# Generados 40 n-gramas de tamaño 3
# Procesando texto 592...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 593...
# Generados 73 n-gramas de tamaño 3
# Procesando texto 594...
# Generados 90 n-gramas de tamaño 3
# Procesando texto 595...
# Generados 44 n-gramas de tamaño 3
# Procesando texto 596...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 597...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 598...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 599...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 600...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 601...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 602...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 603...
# Generados 153 n-gramas de tamaño 3
# Procesando texto 604...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 605...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 606...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 607...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 608...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 609...
# Generados 195 n-gramas de tamaño 3
# Procesando texto 610...
# Generados 56 n-gramas de tamaño 3
# Procesando texto 611...
# Generados 121 n-gramas de tamaño 3
# Procesando texto 612...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 613...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 614...
# Generados 311 n-gramas de tamaño 3
# Procesando texto 615...
# Generados 218 n-gramas de tamaño 3
# Procesando texto 616...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 617...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 618...
# Generados 117 n-gramas de tamaño 3
# Procesando texto 619...
# Generados 75 n-gramas de tamaño 3
# Procesando texto 620...
# Generados 80 n-gramas de tamaño 3
# Procesando texto 621...
# Generados 222 n-gramas de tamaño 3
# Procesando texto 622...
# Generados 140 n-gramas de tamaño 3
# Procesando texto 623...
# Generados 218 n-gramas de tamaño 3
# Procesando texto 624...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 625...
# Generados 76 n-gramas de tamaño 3
# Procesando texto 626...
# Generados 189 n-gramas de tamaño 3
# Procesando texto 627...
# Generados 271 n-gramas de tamaño 3
# Procesando texto 628...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 629...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 630...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 631...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 632...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 633...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 634...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 635...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 636...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 637...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 638...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 639...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 640...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 641...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 642...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 643...
# Generados 55 n-gramas de tamaño 3
# Procesando texto 644...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 645...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 646...
# Generados 88 n-gramas de tamaño 3
# Procesando texto 647...
# Generados 87 n-gramas de tamaño 3
# Procesando texto 648...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 649...
# Generados 62 n-gramas de tamaño 3
# Procesando texto 650...
# Generados 107 n-gramas de tamaño 3
# Procesando texto 651...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 652...
# Generados 71 n-gramas de tamaño 3
# Procesando texto 653...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 654...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 655...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 656...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 657...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 658...
# Generados 99 n-gramas de tamaño 3
# Procesando texto 659...
# Generados 175 n-gramas de tamaño 3
# Procesando texto 660...
# Generados 278 n-gramas de tamaño 3
# Procesando texto 661...
# Generados 118 n-gramas de tamaño 3
# Procesando texto 662...
# Generados 177 n-gramas de tamaño 3
# Procesando texto 663...
# Generados 309 n-gramas de tamaño 3
# Procesando texto 664...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 665...
# Generados 181 n-gramas de tamaño 3
# Procesando texto 666...
# Generados 94 n-gramas de tamaño 3
# Procesando texto 667...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 668...
# Generados 234 n-gramas de tamaño 3
# Procesando texto 669...
# Generados 392 n-gramas de tamaño 3
# Procesando texto 670...
# Generados 55 n-gramas de tamaño 3
# Procesando texto 671...
# Generados 40 n-gramas de tamaño 3
# Procesando texto 672...
# Generados 149 n-gramas de tamaño 3
# Procesando texto 673...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 674...
# Generados 284 n-gramas de tamaño 3
# Procesando texto 675...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 676...
# Generados 142 n-gramas de tamaño 3
# Procesando texto 677...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 678...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 679...
# Generados 110 n-gramas de tamaño 3
# Procesando texto 680...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 681...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 682...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 683...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 684...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 685...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 686...
# Generados 56 n-gramas de tamaño 3
# Procesando texto 687...
# Generados 54 n-gramas de tamaño 3
# Procesando texto 688...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 689...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 690...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 691...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 692...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 693...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 694...
# Generados 91 n-gramas de tamaño 3
# Procesando texto 695...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 696...
# Generados 60 n-gramas de tamaño 3
# Procesando texto 697...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 698...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 699...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 700...
# Generados 69 n-gramas de tamaño 3
# Procesando texto 701...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 702...
# Generados 100 n-gramas de tamaño 3
# Procesando texto 703...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 704...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 705...
# Generados 152 n-gramas de tamaño 3
# Procesando texto 706...
# Generados 61 n-gramas de tamaño 3
# Procesando texto 707...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 708...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 709...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 710...
# Generados 141 n-gramas de tamaño 3
# Procesando texto 711...
# Generados 71 n-gramas de tamaño 3
# Procesando texto 712...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 713...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 714...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 715...
# Generados 145 n-gramas de tamaño 3
# Procesando texto 716...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 717...
# Generados 130 n-gramas de tamaño 3
# Procesando texto 718...
# Generados 185 n-gramas de tamaño 3
# Procesando texto 719...
# Generados 199 n-gramas de tamaño 3
# Procesando texto 720...
# Generados 159 n-gramas de tamaño 3
# Procesando texto 721...
# Generados 248 n-gramas de tamaño 3
# Procesando texto 722...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 723...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 724...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 725...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 726...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 727...
# Generados 65 n-gramas de tamaño 3
# Procesando texto 728...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 729...
# Generados 177 n-gramas de tamaño 3
# Procesando texto 730...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 731...
# Generados 4 n-gramas de tamaño 3
# Procesando texto 732...
# Generados 75 n-gramas de tamaño 3
# Procesando texto 733...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 734...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 735...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 736...
# Generados 52 n-gramas de tamaño 3
# Procesando texto 737...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 738...
# Generados 85 n-gramas de tamaño 3
# Procesando texto 739...
# Generados 132 n-gramas de tamaño 3
# Procesando texto 740...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 741...
# Generados 54 n-gramas de tamaño 3
# Procesando texto 742...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 743...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 744...
# Generados 107 n-gramas de tamaño 3
# Procesando texto 745...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 746...
# Generados 53 n-gramas de tamaño 3
# Procesando texto 747...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 748...
# Generados 84 n-gramas de tamaño 3
# Procesando texto 749...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 750...
# Generados 53 n-gramas de tamaño 3
# Procesando texto 751...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 752...
# Generados 65 n-gramas de tamaño 3
# Procesando texto 753...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 754...
# Generados 60 n-gramas de tamaño 3
# Procesando texto 755...
# Generados 64 n-gramas de tamaño 3
# Procesando texto 756...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 757...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 758...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 759...
# Generados 73 n-gramas de tamaño 3
# Procesando texto 760...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 761...
# Generados 53 n-gramas de tamaño 3
# Procesando texto 762...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 763...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 764...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 765...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 766...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 767...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 768...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 769...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 770...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 771...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 772...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 773...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 774...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 775...
# Generados 32 n-gramas de tamaño 3
# Procesando texto 776...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 777...
# Generados 30 n-gramas de tamaño 3
# Procesando texto 778...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 779...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 780...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 781...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 782...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 783...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 784...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 785...
# Generados 129 n-gramas de tamaño 3
# Procesando texto 786...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 787...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 788...
# Generados 156 n-gramas de tamaño 3
# Procesando texto 789...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 790...
# Generados 430 n-gramas de tamaño 3
# Procesando texto 791...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 792...
# Generados 79 n-gramas de tamaño 3
# Procesando texto 793...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 794...
# Generados 83 n-gramas de tamaño 3
# Procesando texto 795...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 796...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 797...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 798...
# Generados 165 n-gramas de tamaño 3
# Procesando texto 799...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 800...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 801...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 802...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 803...
# Generados 99 n-gramas de tamaño 3
# Procesando texto 804...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 805...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 806...
# Generados 40 n-gramas de tamaño 3
# Procesando texto 807...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 808...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 809...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 810...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 811...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 812...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 813...
# Generados 99 n-gramas de tamaño 3
# Procesando texto 814...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 815...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 816...
# Generados 205 n-gramas de tamaño 3
# Procesando texto 817...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 818...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 819...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 820...
# Generados 180 n-gramas de tamaño 3
# Procesando texto 821...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 822...
# Generados 149 n-gramas de tamaño 3
# Procesando texto 823...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 824...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 825...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 826...
# Generados 62 n-gramas de tamaño 3
# Procesando texto 827...
# Generados 77 n-gramas de tamaño 3
# Procesando texto 828...
# Generados 268 n-gramas de tamaño 3
# Procesando texto 829...
# ...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9380...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 9381...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9382...
# Generados 55 n-gramas de tamaño 3
# Procesando texto 9383...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9384...
# Generados 116 n-gramas de tamaño 3
# Procesando texto 9385...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9386...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 9387...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9388...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 9389...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 9390...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 9391...
# Generados 81 n-gramas de tamaño 3
# Procesando texto 9392...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 9393...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 9394...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 9395...
# Generados 80 n-gramas de tamaño 3
# Procesando texto 9396...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 9397...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 9398...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 9399...
# Generados 86 n-gramas de tamaño 3
# Procesando texto 9400...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 9401...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 9402...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 9403...
# Generados 48 n-gramas de tamaño 3
# Procesando texto 9404...
# Generados 92 n-gramas de tamaño 3
# Procesando texto 9405...
# Generados 99 n-gramas de tamaño 3
# Procesando texto 9406...
# Generados 151 n-gramas de tamaño 3
# Procesando texto 9407...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9408...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 9409...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 9410...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 9411...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 9412...
# Generados 99 n-gramas de tamaño 3
# Procesando texto 9413...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 9414...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9415...
# Generados 62 n-gramas de tamaño 3
# Procesando texto 9416...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9417...
# Generados 58 n-gramas de tamaño 3
# Procesando texto 9418...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 9419...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9420...
# Generados 63 n-gramas de tamaño 3
# Procesando texto 9421...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9422...
# Generados 56 n-gramas de tamaño 3
# Procesando texto 9423...
# Generados 187 n-gramas de tamaño 3
# Procesando texto 9424...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 9425...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9426...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 9427...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9428...
# Generados 85 n-gramas de tamaño 3
# Procesando texto 9429...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9430...
# Generados 291 n-gramas de tamaño 3
# Procesando texto 9431...
# Generados 54 n-gramas de tamaño 3
# Procesando texto 9432...
# Generados 68 n-gramas de tamaño 3
# Procesando texto 9433...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9434...
# Generados 50 n-gramas de tamaño 3
# Procesando texto 9435...
# Generados 88 n-gramas de tamaño 3
# Procesando texto 9436...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 9437...
# Generados 45 n-gramas de tamaño 3
# Procesando texto 9438...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9439...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 9440...
# Generados 76 n-gramas de tamaño 3
# Procesando texto 9441...
# Generados 41 n-gramas de tamaño 3
# Procesando texto 9442...
# Generados 189 n-gramas de tamaño 3
# Procesando texto 9443...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9444...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 9445...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 9446...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 9447...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9448...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 9449...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 9450...
# Generados 49 n-gramas de tamaño 3
# Procesando texto 9451...
# Generados 47 n-gramas de tamaño 3
# Procesando texto 9452...
# Generados 26 n-gramas de tamaño 3
# Procesando texto 9453...
# Generados 97 n-gramas de tamaño 3
# Procesando texto 9454...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9455...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 9456...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 9457...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9458...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 9459...
# Generados 6 n-gramas de tamaño 3
# Procesando texto 9460...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9461...
# Generados 9 n-gramas de tamaño 3
# Procesando texto 9462...
# Generados 52 n-gramas de tamaño 3
# Procesando texto 9463...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9464...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9465...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 9466...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 9467...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 9468...
# Generados 126 n-gramas de tamaño 3
# Procesando texto 9469...
# Generados 197 n-gramas de tamaño 3
# Procesando texto 9470...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 9471...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 9472...
# Generados 85 n-gramas de tamaño 3
# Procesando texto 9473...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 9474...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 9475...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 9476...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 9477...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9478...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9479...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 9480...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 9481...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9482...
# Generados 45 n-gramas de tamaño 3
# Procesando texto 9483...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9484...
# Generados 73 n-gramas de tamaño 3
# Procesando texto 9485...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 9486...
# Generados 125 n-gramas de tamaño 3
# Procesando texto 9487...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 9488...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 9489...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9490...
# Generados 101 n-gramas de tamaño 3
# Procesando texto 9491...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 9492...
# Generados 118 n-gramas de tamaño 3
# Procesando texto 9493...
# Generados 57 n-gramas de tamaño 3
# Procesando texto 9494...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9495...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9496...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9497...
# Generados 35 n-gramas de tamaño 3
# Procesando texto 9498...
# Generados 63 n-gramas de tamaño 3
# Procesando texto 9499...
# Generados 46 n-gramas de tamaño 3
# Procesando texto 9500...
# Generados 156 n-gramas de tamaño 3
# Procesando texto 9501...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 9502...
# Generados 217 n-gramas de tamaño 3
# Procesando texto 9503...
# Generados 264 n-gramas de tamaño 3
# Procesando texto 9504...
# Generados 106 n-gramas de tamaño 3
# Procesando texto 9505...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 9506...
# Generados 85 n-gramas de tamaño 3
# Procesando texto 9507...
# Generados 37 n-gramas de tamaño 3
# Procesando texto 9508...
# Generados 51 n-gramas de tamaño 3
# Procesando texto 9509...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 9510...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9511...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 9512...
# Generados 42 n-gramas de tamaño 3
# Procesando texto 9513...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 9514...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 9515...
# Generados 67 n-gramas de tamaño 3
# Procesando texto 9516...
# Generados 143 n-gramas de tamaño 3
# Procesando texto 9517...
# Generados 147 n-gramas de tamaño 3
# Procesando texto 9518...
# Generados 127 n-gramas de tamaño 3
# Procesando texto 9519...
# Generados 16 n-gramas de tamaño 3
# Procesando texto 9520...
# Generados 147 n-gramas de tamaño 3
# Procesando texto 9521...
# Generados 85 n-gramas de tamaño 3
# Procesando texto 9522...
# Generados 36 n-gramas de tamaño 3
# Procesando texto 9523...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 9524...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9525...
# Generados 72 n-gramas de tamaño 3
# Procesando texto 9526...
# Generados 78 n-gramas de tamaño 3
# Procesando texto 9527...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9528...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 9529...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 9530...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 9531...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9532...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9533...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9534...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9535...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9536...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 9537...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9538...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 9539...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 9540...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 9541...
# Generados 110 n-gramas de tamaño 3
# Procesando texto 9542...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 9543...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 9544...
# Generados 53 n-gramas de tamaño 3
# Procesando texto 9545...
# Generados 103 n-gramas de tamaño 3
# Procesando texto 9546...
# Generados 61 n-gramas de tamaño 3
# Procesando texto 9547...
# Generados 140 n-gramas de tamaño 3
# Procesando texto 9548...
# Generados 53 n-gramas de tamaño 3
# Procesando texto 9549...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9550...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9551...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9552...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 9553...
# Generados 158 n-gramas de tamaño 3
# Procesando texto 9554...
# Generados 22 n-gramas de tamaño 3
# Procesando texto 9555...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 9556...
# Generados 14 n-gramas de tamaño 3
# Procesando texto 9557...
# Generados 24 n-gramas de tamaño 3
# Procesando texto 9558...
# Generados 51 n-gramas de tamaño 3
# Procesando texto 9559...
# Generados 71 n-gramas de tamaño 3
# Procesando texto 9560...
# Generados 61 n-gramas de tamaño 3
# Procesando texto 9561...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9562...
# Generados 137 n-gramas de tamaño 3
# Procesando texto 9563...
# Generados 98 n-gramas de tamaño 3
# Procesando texto 9564...
# Generados 56 n-gramas de tamaño 3
# Procesando texto 9565...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9566...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9567...
# Generados 28 n-gramas de tamaño 3
# Procesando texto 9568...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9569...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9570...
# Generados 38 n-gramas de tamaño 3
# Procesando texto 9571...
# Generados 7 n-gramas de tamaño 3
# Procesando texto 9572...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 9573...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 9574...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 9575...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 9576...
# Generados 58 n-gramas de tamaño 3
# Procesando texto 9577...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9578...
# Generados 74 n-gramas de tamaño 3
# Procesando texto 9579...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 9580...
# Generados 181 n-gramas de tamaño 3
# Procesando texto 9581...
# Generados 141 n-gramas de tamaño 3
# Procesando texto 9582...
# Generados 98 n-gramas de tamaño 3
# Procesando texto 9583...
# Generados 58 n-gramas de tamaño 3
# Procesando texto 9584...
# Generados 43 n-gramas de tamaño 3
# Procesando texto 9585...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 9586...
# Generados 23 n-gramas de tamaño 3
# Procesando texto 9587...
# Generados 29 n-gramas de tamaño 3
# Procesando texto 9588...
# Generados 25 n-gramas de tamaño 3
# Procesando texto 9589...
# Generados 84 n-gramas de tamaño 3
# Procesando texto 9590...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9591...
# Generados 130 n-gramas de tamaño 3
# Procesando texto 9592...
# Generados 31 n-gramas de tamaño 3
# Procesando texto 9593...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 9594...
# Generados 56 n-gramas de tamaño 3
# Procesando texto 9595...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 9596...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9597...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 9598...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9599...
# Generados 10 n-gramas de tamaño 3
# Procesando texto 9600...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9601...
# Generados 406 n-gramas de tamaño 3
# Procesando texto 9602...
# Generados 224 n-gramas de tamaño 3
# Procesando texto 9603...
# Generados 21 n-gramas de tamaño 3
# Procesando texto 9604...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 9605...
# Generados 59 n-gramas de tamaño 3
# Procesando texto 9606...
# Generados 123 n-gramas de tamaño 3
# Procesando texto 9607...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 9608...
# Generados 51 n-gramas de tamaño 3
# Procesando texto 9609...
# Generados 94 n-gramas de tamaño 3
# Procesando texto 9610...
# Generados 109 n-gramas de tamaño 3
# Procesando texto 9611...
# Generados 227 n-gramas de tamaño 3
# Procesando texto 9612...
# Generados 87 n-gramas de tamaño 3
# Procesando texto 9613...
# Generados 238 n-gramas de tamaño 3
# Procesando texto 9614...
# Generados 160 n-gramas de tamaño 3
# Procesando texto 9615...
# Generados 236 n-gramas de tamaño 3
# Procesando texto 9616...
# Generados 27 n-gramas de tamaño 3
# Procesando texto 9617...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 9618...
# Generados 34 n-gramas de tamaño 3
# Procesando texto 9619...
# Generados 68 n-gramas de tamaño 3
# Procesando texto 9620...
# Generados 19 n-gramas de tamaño 3
# Procesando texto 9621...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9622...
# Generados 15 n-gramas de tamaño 3
# Procesando texto 9623...
# Generados 12 n-gramas de tamaño 3
# Procesando texto 9624...
# Generados 20 n-gramas de tamaño 3
# Procesando texto 9625...
# Generados 11 n-gramas de tamaño 3
# Procesando texto 9626...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9627...
# Generados 8 n-gramas de tamaño 3
# Procesando texto 9628...
# Generados 18 n-gramas de tamaño 3
# Procesando texto 9629...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9630...
# Generados 151 n-gramas de tamaño 3
# Procesando texto 9631...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 9632...
# Generados 160 n-gramas de tamaño 3
# Procesando texto 9633...
# Generados 17 n-gramas de tamaño 3
# Procesando texto 9634...
# Generados 33 n-gramas de tamaño 3
# Procesando texto 9635...
# Generados 13 n-gramas de tamaño 3
# Procesando texto 9636...
# Generados 82 n-gramas de tamaño 3
# Procesando texto 9637...
# Generados 134 n-gramas de tamaño 3
# Procesando texto 9638...
# Generados 184 n-gramas de tamaño 3
# Procesando texto 9639...
# Generados 275 n-gramas de tamaño 3
# Procesando texto 9640...
# Generados 389 n-gramas de tamaño 3
# Procesando texto 9641...
# Generados 267 n-gramas de tamaño 3
# Procesando texto 9642...
# Generados 287 n-gramas de tamaño 3
# Procesando texto 9643...
# Generados 138 n-gramas de tamaño 3
# Procesando texto 9644...
# Generados 123 n-gramas de tamaño 3
# Procesando texto 9645...
# Generados 118 n-gramas de tamaño 3
# Procesando texto 9646...
# Generados 147 n-gramas de tamaño 3
# Procesando texto 9647...
# Generados 150 n-gramas de tamaño 3
# Procesando texto 9648...
# Generados 39 n-gramas de tamaño 3
# Procesando texto 9649...
# Generados 229 n-gramas de tamaño 3

# %%
for prefix in [(BOS, BOS), (BOS, 'It'), ('It', 'was'), ('my', 'dear')]:
    print(*prefix)
    sorted_probs = sorted(model[prefix].items(), key=lambda x: -x[1])
    for k, v in sorted_probs[:5]:
        print(f'\t{k}\t{v:.4f}')
    print(f'\t[{len(sorted_probs)-5} more...]')
# Out:
# <BOS> <BOS>
# 	"	0.8073
# 	The	0.0304
# 	Holmes	0.0230
# 	I	0.0167
# 	It	0.0141
# 	[206 more...]
# <BOS> It
# 	was	0.8235
# 	is	0.0515
# 	may	0.0221
# 	had	0.0147
# 	seemed	0.0074
# 	[11 more...]
# It was
# 	a	0.1888
# 	the	0.0686
# 	not	0.0562
# 	only	0.0312
# 	an	0.0250
# 	[184 more...]
# my dear
# 	Watson	0.5612
# 	fellow	0.1429
# 	sir	0.0918
# 	young	0.0510
# 	Von	0.0204
# 	[12 more...]

# %% [markdown]
# Do these probabilities look reasonable? How can we systematically evaluate the quality of our model? We'll cover this in the next lesson!

# %% [markdown]
# ## Optional Extra:
#  - Smoothing techniques, such as [Laplace Smoothing](https://en.wikipedia.org/wiki/Additive_smoothing), are often added to n-gram language models to deal with probabilities of 0. How might you modify your code to include smoothing?
